# %%
print("Hello, World aus dem Jupyter Notebook!")
# Out:
# Hello, World aus dem Jupyter Notebook!

# %%
import matplotlib.pyplot as plt

xs = list(range(11))
ys = [x * x for x in xs]
plt.plot(xs, ys)
plt.show()

# %%
# !uv add tqdm
# Damit das funktioniert, musste ich vorher in vscode die Variabel inheritEnv auf true setzen.
# Aber schön ist das ja nicht - im Prinzip kann ich als Entwickler des Projekts
# ja alle Pakete in in die pyproject.toml schreiben, die ich brauche. oder ich
# rufe uv add auf, dann wird das Paket auch in die pyproject.toml geschrieben.
# Wenn ich das Projet dann jemand anderen gebe, dann kann der das Projekt
# mit uv run main.py ausführen und es wird automatisch eine virtuelle Umgebung
# angelegt und die Abhängigkeiten installiert.
# Out:
# Resolved 44 packages in 0.55ms
# Audited 39 packages in 0.01ms

# %%
import tqdm
from time import sleep

for i in tqdm.tqdm(range(100)):
    sleep(0.05)
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 18.45it/s]
